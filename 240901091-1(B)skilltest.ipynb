# %%
import numpy as np
A = np.array([[2, 3],
              [1, 2]])
b = np.array([5, 3])
x = np.linalg.solve(A, b)
print("Matrix A:")
print(A)
print("\nVector b:")
print(b)
print("\nSolution vector x:")
print(x)
# Out:
# Matrix A:
# [[2 3]
#  [1 2]]
#
# Vector b:
# [5 3]
#
# Solution vector x:
# [1. 1.]
